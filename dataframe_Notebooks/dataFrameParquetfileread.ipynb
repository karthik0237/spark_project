# %%
parquetdf = spark.read.format("parquet").load("/Workspace/Users/karthikkolluru123@gmail.com/file5.parquet")
parquetdf.show()

print("===select===")
parquetdf.createOrReplaceTempView("cust")
spark.sql("select * from cust").show(10) # showing only top 10 rows

print("===Printing schema of dataframe===")
parquetdf.printSchema()
