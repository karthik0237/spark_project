# %%
csvdf = spark.read.format("csv").option('header','true').load("/Workspace/Users/karthikkolluru123@gmail.com/df1.csv")
print('===reading csv data===')
csvdf.show()
# using display() to display the dataframe for analysis
csvdf.display()

jsondf = spark.read.format("json").load("/Workspace/Users/karthikkolluru123@gmail.com/file4.json")
print('===reading json data===')
jsondf.show()

orcdf = spark.read.format('orc').load('/Workspace/Users/karthikkolluru123@gmail.com/data.orc')
print('===reading orc data===')
orcdf.show()
